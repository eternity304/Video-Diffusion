# %%
import argparse
import os

os.chdir("..")

import math
import yaml
import logging
import random
import numpy as np
import sys
import imageio
import torch

from accelerate import Accelerator
from accelerate.utils import DistributedDataParallelKwargs, ProjectConfiguration, set_seed
from accelerate.logging import get_logger

from data.VideoDataset import VideoDataset 
from torch.utils.data import DataLoader, DistributedSampler

from diffusers import AutoencoderKLCogVideoX, CogVideoXDDIMScheduler
from model.cap_transformer import CAPVideoXTransformer3DModel

from inference._inference_pipeline import *
from data.VideoDataset import *
from model.flameObj import *

import trimesh

os.getcwd()
# Out:
# '/nfs/horai.dgpsrv/ondemand28/harryscz/diffusion'

# %%
flamePath = flamePath = "/scratch/ondemand28/harryscz/head_audio/head/code/flame/flame2023_no_jaw.npz"
sourcePath = "/scratch/ondemand28/harryscz/head_audio/head/data/vfhq-fit"
dataPath = [os.path.join(os.path.join(sourcePath, data), "fit.npz") for data in os.listdir(sourcePath)]
seqPath = "/scratch/ondemand28/harryscz/head/_-91nXXjrVo_00/fit.npz"

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
head = Flame(flamePath, device="cuda")
head.loadSequence(dataPath[3])
seq = head.LSB(rotation=False)
uvMesh = head.convertUV()
uv = head.get_uv_animation(uvMesh, savePath="flameOut/a.mp4")
sampled = head.sampleFromUV(uv.squeeze(0), "flameOut/b.mp4")
final = head.sampleTo3D(sampledUV=sampled, savePath="flameOut/c.mp4", dist=1.2)
# Out:
# /nfs/horai.dgpsrv/ondemand28/harryscz/pytorch3d/pytorch3d/io/obj_io.py:551: UserWarning: Mtl file does not exist: /scratch/ondemand28/harryscz/head_audio/head/template.mtl
#   warnings.warn(f"Mtl file does not exist: {f}")

# %%
faces = head.faces3d.cpu().numpy()
verts = final[10, ...].cpu().numpy()

trimesh.Trimesh(vertices=verts, faces=faces, process=True).export("flameOut/i.ply")
# Out:
# b'ply\nformat binary_little_endian 1.0\ncomment https://github.com/mikedh/trimesh\nelement vertex 3908\nproperty float x\nproperty float y\nproperty float z\nelement face 9976\nproperty list uchar int vertex_indices\nend_header\n)\x9b\x1e\xbe9g\xa1\xbe"_\xdb\xbf\xd5I\x1e\xbe\xf7_\xa0\xbe\x1aR\xdb\xbf\xff& \xbem\xf1\x9e\xbe\xf6\xb4\xdc\xbf\x12\xd8\x1c\xbe\xea\xd9\x9d\xbefD\xdc\xbf\xb5-\x1b\xbe\xd4^\x9b\xbe|\xf0\xdb\xbf\xe8\x9f\x1e\xbe\xbd\xff\x9b\xbejO\xdc\xbf\xbc\x95[\xbe\x9eJ\xbe\xbe\xbdc\xe7\xbfZqr\xbe\x17\xa2\xbd\xbe-1\xe9\xbf\xecBu\xbe\xe2\x02\xc6\xbe\x86l\xe8\xbf\xd8\xfb`\xbe:\xa0\xc7\xbe\xa7\xe3\xe6\xbf\xde&I\xbelq\xd9\xbe\xdb\x98\xe2\xbfn\xc7N\xbe\xd0\x8b\xd3\xbe~\xc0\xe3\xbfNhS\xbe>#\xdd\xbe\x90\x97\xe4\xbf"\x11H\xbe\xea\x89\xdf\xbe^}\xe2\xbf\xae\x8c]\xbec\x0eq\xbea\xf1\xca\xbf=\x0fT\xbe\xf6\x9bq\xbeT\xc9\xcb\xbf\xd3\xdeT\xbe\x0cj{\xbe \x18\xcb\xbf\xb1\x1a\xc1\xbe22\xa0\xbe\xfb\xfa\xdb\xbf\xac\xf3\xc0\xbe\xf94\xa1\xbe\xb8\x06\xdc\xbfSB\xbf\xbeN\x9b\x9e\xbe\xee\x83\xdd\xbf]\xf9\xc0\xbe\x1es\x9d\xbe\xf4\xd0\xdc\xbf2Y\xc2\xbe<\x96\x9a\xbe\x84_\xdc\xbf\xe3\xc4\xc0\xbe\x837\x99\xbe\x92\x02\xdc\xbf:\xd7_\xbe\x8f\ry\xbe\x93e\xca\xbf\x98\x99\x0b\xbev\xae\x8c\xbe\xceE\xdd\xbf\xee\xf7\x08\xbe\x1e>\x8e\xbeD\x87\xdd\xbf\xa3\x04\x0e\xbe\xf6\xb7\x99\xbe \xc3\xde\xbfLw\r\xbe\x8d\x17\x92\xbe\x82(\xde\xbf\x07\xc6\x0c\xbe\xdc\x85\x90\xbe\xe8\xcd\xdd\xbf\xcaV\r\xbe\x87T\xa3\xbe\xda\xa6\xde\xbf\xd5\x9f\r\xbe\x06\xe5\x9d\xbe\xce\xc3\xde\xbf\x10\x9c\x0c\xbe\xcdW\x9e\xbe\xbcT\xdf\xbf\x91\x16 \xbe\xf3\xaf\xb3\xbe>\x04\xdb\xbf\xf5\x8b\x1f\xbe\xbe\xa6\xb1\xbeY1\xdb\xbf))\x1e\xbe\x971\xb3\xbe\x1b]\xdb\xbf\x00\x86 \xbeX\xa8\xb4\xbe\xf2\xd5\xda\xbfb\xd0\x1f\xbe\x0e\xc6\xb7\xbe\xea\xbd\xda\xbf\x04\x92\x1c\xbe\xd7\x17\xb5\xbe\xfc\x8a\xdb\xbf\xddw\x18\xbe\xe5\xa6\xb7\xbef\x07\xdc\xbf\xb4\x95\x1d\xbe\xe5\x07\xb9\xbe\xe0\x11\xdb\xbf\\\x84\x17\xbe\x0f\xcf\x8d\xbe#E\xdc\xbf\xfbh\x15\xbe\xa4\x03\x8f\xbe\xce\xd9\xdb\xbf_8\x18\xbe\x9cv\x8f\xbe>\xbf\xdb\xbf\x16J\x19\xbe\xa1\xbd\x8e\xbeP\x08\xdc\xbf\xe5\x81\x18\xbe\xb9\xf5\xa3\xbeyO\xdf\xbf\xb4\xa5\x1c\xbev\x9c\xa9\xbeT\xff\xde\xbf\x95\x92\x0c\xbe\x92\xd1\xa5\xbe\x01\'\xe0\xbf\xef\xe1\x0e\xbewq\xa2\xbe\xaa6\xe0\xbfxf\x10\xbe\xfa1\x92\xbe\xad\xa5\xdc\xbfs\xb0\r\xbeo\x08\x91\xbe\x84\xdc\xdc\xbf\xca\xf7\x11\xbe\xd7W\x91\xbe\xea\xb2\xdc\xbf\x13\x7f\x11\xbeso\x8c\xbe\xb4\xaf\xdd\xbf\xaeP\x0e\xbe\xff\x19\x8c\xbe\xb0\xfc\xdd\xbf[d#\xbev\x8c\xae\xbe\xc7u\xda\xbf\xfa\xfd#\xbe\n\t\xac\xbe\xfc\n\xda\xbfa\xdb!\xbe\x97\xae\xaa\xbe\x18\x86\xda\xbf\x18C"\xbe\xdfN\xac\xbez\xc1\xda\xbf\xb2m\x1d\xbew/\x9f\xbe\xf0d\xdc\xbf\xe1\xac\x1b\xbeH\xe9\x9c\xbec\xc3\xdb\xbf!\x86\x11\xbe\xc0Y\xac\xbe\xf6\xfa\xdd\xbfP\x92\x12\xbe(\xbd\xaa\xbe&\xc6\xdd\xbf\x19\xa2\x0f\xbeb1\xa8\xbe\x90;\xde\xbfb\xbe\r\xbe\xfb_\xa8\xbe\xd9\x80\xde\xbf+\x86\x16\xbeC\x1d\xaa\xbeJ\x10\xde\xbf\x05\x1c\x13\xbem\xdb\xa6\xbeic\xde\xbf\x85\xa2\x0f\xbe\xff\xa5\xa6\xbe\xd5Q\xde\xbf\x9e\xc8\x12\xbe\xc2\x7f\xa8\xbeFG\xde\xbfd3\x0f\xbe\x94\xa5\x8e\xbe\x9aO\xdc\xbf\x81\xee\x12\xbe\x05\x83\x8f\xbe0\xee\xdb\xbf\x96=\x15\xbe\xfac\x96\xbe\x8a\x02\xdf\xbfc\x1e\x19\xbe9e\x94\xbe\x02\xfb\xdd\xbf\xfe\xd5\x0b\xbe\xe2\x11\x91\xbe\xfce\xdd\xbf\xaf\xc7\x0e\xbei\xe1\x90\xbeZ\x07\xdd\xbfR\xe8\x17\xbe\xb1\xf7\x95\xbe\x81o\xdb\xbfkv\x16\xbe&\x94\x94\xbe\xfe{\xdb\xbf\xd7U\x16\xbe\xf8x\x95\xbe\x94\xa0\xdb\xbf\x84r\x16\xbe\xbeZ\x96\xbe\\\xc9\xdb\xbf\x12K\x1c\xbe1\xbd\xb3\xbe\xca\xa8\xdb\xbf\x9bB\x1d\xbe\xe0+\xb2\xbe\xb6\x80\xdd\xbf\x96\x15\x19\xbe\xc9\x8a\xb2\xbet\xdf\xdd\xbf\xe8R\x14\xbe\x869\xae\xbe<\xe9\xde\xbf\xad\x02\x18\xbed*\xac\xbe\xbc\xc8\xde\xbf;)$\xbe\xe1\x15\xb4\xbec[\xda\xbfXx!\xbe\x1a\x16\xb3\xbe\x84\xc6\xda\xbf\xa2S"\xbe}\xeb\xb4\xbe\xear\xda\xbf\x8b\xa5\x15\xbeO\x11\x93\xbe\xf3\x87\xdb\xbf\x99\xab\x13\xbe\x7fT\x93\xbe\x14\xd7\xdb\xbf\xe9 \x15\xbe\x9d\xf8\x93\xbe\x90\xa7\xdb\xbf\xb6"\r\xbe\x9f\xa7\x94\xbeW\x81\xde\xbf\xb2\xad\x10\xbe\xf7Z\x91\xbe\xf5_\xdd\xbf:\xff\x12\xbe{+\x9e\xbe\x0e\xf1\xdd\xbf\xf0U\x0f\xbe\xea\x96\xa1\xbe\xd8O\xde\xbf8\x87\xa2\xbe6a\xbe\xbes\xe0\xe7\xbf.0 ...

# %%
uvs = head.batch_uv(dataPath[i:i+1], resolution=256, sample_frames=29, rotation=False)
uvs.permute(0, 1, 4, 2, 3).shape
# Out:
# /nfs/horai.dgpsrv/ondemand28/harryscz/pytorch3d/pytorch3d/io/obj_io.py:551: UserWarning: Mtl file does not exist: /scratch/ondemand28/harryscz/head_audio/head/template.mtl
#   warnings.warn(f"Mtl file does not exist: {f}")
# torch.Size([1, 29, 256, 256, 3])

# %%
uvs = head.batch_uv(dataPath[i:i+1], resolution=256, sample_frames=29, rotation=False) # load UVs of shape B, F, C, H, W
ref_frame = uvs[:, 0, :, :, :].unsqueeze(1) # B, 1, C, H, W
# Out:
# /nfs/horai.dgpsrv/ondemand28/harryscz/pytorch3d/pytorch3d/io/obj_io.py:551: UserWarning: Mtl file does not exist: /scratch/ondemand28/harryscz/head_audio/head/template.mtl
#   warnings.warn(f"Mtl file does not exist: {f}")

# %%
sampled = head.sampleFromUV(uvs.squeeze(0), "flameOut/_b.mp4")
final = head.sampleTo3D(sampledUV=sampled, savePath="flameOut/_c.mp4", dist=1.2)

faces = head.faces3d.cpu().numpy()
verts = final[0, ...].cpu().numpy()

trimesh.Trimesh(vertices=verts, faces=faces, process=True).export("flameOut/_i.ply")
# Out:
# b'ply\nformat binary_little_endian 1.0\ncomment https://github.com/mikedh/trimesh\nelement vertex 3911\nproperty float x\nproperty float y\nproperty float z\nelement face 9976\nproperty list uchar int vertex_indices\nend_header\n\n\x08\x1f\xbeP\xa8\xa1\xbe\x06M\xdb\xbfV\xb0\x1e\xbe$\xa2\xa0\xbeR?\xdb\xbf\xa5\x98 \xbe\xb5%\x9f\xbel\x9f\xdc\xbf\x8c?\x1d\xbe\x90\x14\x9e\xbeH.\xdc\xbfh\x86\x1b\xbe)\x9f\x9b\xbe\xe1\xd8\xdb\xbfF\x02\x1f\xbe\x0b;\x9c\xbe\x048\xdc\xbf\x84\x15\\\xbe\xdaq\xbe\xbeB^\xe7\xbf\xd0\xd2r\xbeb\xa8\xbd\xbe\t1\xe9\xbf\xce\xe3u\xbe&\x1c\xc6\xbe\x0cn\xe8\xbf\xce\xd1a\xbee\xdb\xc7\xbe\xe8\xde\xe6\xbf\xdc\xcdJ\xbe<\xcd\xd9\xbe\xcc\x87\xe2\xbfK\x1dP\xbe\t\xdd\xd3\xbe\x1a\xb4\xe3\xbf\xe2*U\xbe\x81\x94\xdd\xbe\xe6\x89\xe4\xbfj\x14J\xbe\x12\xf7\xdf\xbe\x19j\xe2\xbf\xca\\X\xbeU\x81f\xbe\xc4p\xcb\xbff\xf8N\xbe\xa3\x80g\xbefa\xcc\xbfs\xd7O\xbe:\xc5p\xbe\x9c\xc8\xcb\xbf\x0e\xd5\xc0\xbe\x8b5\xa0\xbe\xf8\x0c\xdc\xbf\x8e\xa7\xc0\xbe\xa45\xa1\xbeJ\x19\xdc\xbf\x99\xfe\xbe\xbe\xa5\x8e\x9e\xbef\x93\xdd\xbf\xd5\xc0\xc0\xbe\x16n\x9d\xbe\xe6\xe0\xdc\xbf:-\xc2\xbe\x9b\x98\x9a\xbeWn\xdc\xbfw\x9a\xc0\xbe$9\x99\xbe\x13\x10\xdc\xbf[9Z\xbe;\xc7m\xbe\xa4\xe6\xca\xbf\xc9\xaa\x0b\xbe*\x11\x8d\xbe\xb0\x1c\xdd\xbf\xbb\x15\t\xbei\xa3\x8e\xbe\xd3]\xdd\xbf\x06\x80\x0e\xbe\xf0\x02\x9a\xbe\xb4\x9f\xde\xbfJ\xb8\r\xbe\x12q\x92\xbe8\x01\xde\xbfN\xfd\x0c\xbe\xf6\xe3\x90\xbe:\xa6\xdd\xbf\x1d\x12\x0e\xbe \xa0\xa3\xbeB\x89\xde\xbf\x19:\x0e\xbe\xfc/\x9e\xbe\xc2\xa2\xde\xbf\xa1:\r\xbe\xea\xa2\x9e\xbeL3\xdf\xbf\xb5\xeb \xbe\x08\xee\xb3\xbev\xfc\xda\xbf5f \xbe\x8c\xe7\xb1\xbe\xde\'\xdb\xbf\x01\x14\x1f\xbe\x1cv\xb3\xbe\xdeS\xdb\xbf\xa1Y!\xbe\x97\xe7\xb4\xbe\x19\xcf\xda\xbf=\xb5 \xbe\xcf\x0b\xb8\xbe\xe1\xb8\xda\xbfe\x8d\x1d\xbeEa\xb5\xbe\x11\x82\xdb\xbfL\x83\x19\xbe\x88\xef\xb7\xbeV\xfe\xdb\xbf\xbe\x93\x1e\xbe\xf2T\xb9\xbe!\x0c\xdb\xbf1\x88\x17\xbe\x15)\x8e\xbe&!\xdc\xbf\x0fy\x15\xbe)b\x8f\xbe\x96\xb6\xdb\xbf\xddD\x18\xbe\xb2\xcf\x8f\xbeB\x9d\xdb\xbf\x1cM\x19\xbe\xa2\x12\x8f\xbe~\xe5\xdb\xbf\x00<\x19\xbe\xfe#\xa4\xbe\xd91\xdf\xbf\xae\x83\x1d\xbe>\xbb\xa9\xbe|\xe6\xde\xbf\xbc^\r\xbe0\x10\xa6\xbet\x08\xe0\xbf\xe1\x94\x0f\xbe\xba\xaf\xa2\xbeW\x16\xe0\xbf\xb9\x91\x10\xbe\xcb\x8f\x92\xbe\x9c\x82\xdc\xbf\x1e\xd8\r\xbe\x1cj\x91\xbek\xb7\xdc\xbf4*\x12\xbe\x7f\xaf\x91\xbe\x80\x8f\xdc\xbf\xe4\x86\x11\xbe9\xc9\x8c\xbe$\x87\xdd\xbf\xa4]\x0e\xbe\x9cu\x8c\xbe\xf2\xd2\xdd\xbf@\x08$\xbe>\xc3\xae\xbe\x19l\xda\xbfWv$\xbe\xc64\xac\xbet\x00\xda\xbfj}"\xbeN\xeb\xaa\xbe\xc3y\xda\xbf`\xf9"\xbe\x86\x8b\xac\xbe\xe0\xb5\xda\xbf\xac\xdc\x1d\xbe\xf0g\x9f\xbe\xa4O\xdc\xbfb\n\x1c\xbe\x8e)\x9d\xbe.\xad\xdb\xbf\x14\x80\x12\xbe\xa5\xa7\xac\xbeo\xe5\xdd\xbf@\x80\x13\xbe\x1e\x08\xab\xbe\xa2\xb0\xdd\xbf |\x10\xbe\x9f{\xa8\xbe\xc8"\xde\xbfa\x9d\x0e\xbeE\xad\xa8\xbe\xc4f\xde\xbf\xf6e\x17\xbe\xaa^\xaa\xbe\xcc\xfb\xdd\xbf\x10\xe0\x13\xbe\xb4\x1c\xa7\xbe4K\xde\xbfol\x10\xbe\xe8\xed\xa6\xbe\xfe7\xde\xbf\x98\x9d\x13\xbe)\xc3\xa8\xbeL0\xde\xbf\x86J\x0f\xbeQ\x07\x8f\xbed*\xdc\xbf\x85\x05\x13\xbe\x0f\xe3\x8f\xbe\xc6\xca\xdb\xbf\xe6\x80\x15\xbe\xbe\xa6\x96\xbe\xca\xdd\xde\xbf\x831\x19\xbe\xa0\xaa\x94\xbe)\xd7\xdd\xbf\xa3\x06\x0c\xbeZu\x91\xbe\xd0>\xdd\xbf\x92\xf9\x0e\xbeC?\x91\xbe\xb0\xe1\xdc\xbf\xde\x1f\x18\xbe9H\x96\xbe\x9eS\xdb\xbf\x9b\xa6\x16\xbe\xb1\xe8\x94\xbe\x83^\xdb\xbf\xda\x8b\x16\xbe\r\xcb\x95\xbe\xcc\x83\xdb\xbf\x18\xae\x16\xbe\xe8\xa9\x96\xbeL\xad\xdb\xbf\x1fF\x1d\xbe\xba\x05\xb4\xbe\xd4\x9e\xdb\xbf\xfcR\x1e\xbe\xb4V\xb2\xbe\xe7p\xdd\xbfz-\x1a\xbe\n\xbb\xb2\xbe\xa0\xce\xdd\xbf\xeeZ\x15\xbe\xafl\xae\xbed\xd2\xde\xbff\x03\x19\xbe\x88R\xac\xbe\x0c\xb1\xde\xbfx\xd9$\xbe\xc0E\xb4\xbe\x9cU\xda\xbf\xca>"\xbe,O\xb3\xbe\xf3\xbe\xda\xbf}\x15#\xbeE%\xb5\xbe m\xda\xbf\xb7\xcd\x15\xbe\xbai\x93\xbe\xd3h\xdb\xbf\x10\xd7\x13\xbe\xc2\xae\x93\xbeD\xb7\xdb\xbf\xd3N\x15\xbe\xa1O\x94\xbe\n\x89\xdb\xbf6u\r\xbe\xaf\xf9\x94\xbez[\xde\xbf\x98\xe8\x10\xbe\xae\xaf\x91\xbe^:\xdd\xbfb\x88\x13\xbe\xafm\x9e\xbe.\xd3\xdd\xbf{\xfd\x0f\xbe$\xde\xa1\xbea2\xde\xbf\xce\xb2\xa2\xbe\x994\xbe\xbeq\xf1\xe7\xbf\xecU\x96\xbe\x8a\xbf\xbd\ ...

# %%
vae = AutoencoderKLCogVideoX.from_pretrained(
    "/scratch/ondemand28/harryscz/model/CogVideoX-2b", subfolder="vae"
)
vae.to("cuda")
# Out:
# AutoencoderKLCogVideoX(
#   (encoder): CogVideoXEncoder3D(
#     (conv_in): CogVideoXCausalConv3d(
#       (conv): CogVideoXSafeConv3d(3, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#     )
#     (down_blocks): ModuleList(
#       (0): CogVideoXDownBlock3D(
#         (resnets): ModuleList(
#           (0-2): 3 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): CogVideoXDownsample3D(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (1): CogVideoXDownBlock3D(
#         (resnets): ModuleList(
#           (0): CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (conv_shortcut): CogVideoXSafeConv3d(128, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (1-2): 2 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): CogVideoXDownsample3D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (2): CogVideoXDownBlock3D(
#         (resnets): ModuleList(
#           (0-2): 3 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): CogVideoXDownsample3D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (3): CogVideoXDownBlock3D(
#         (resnets): ModuleList(
#           (0): CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (conv_shortcut): CogVideoXSafeConv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (1-2): 2 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#       )
#     )
#     (mid_block): CogVideoXMidBlock3D(
#       (resnets): ModuleList(
#         (0-1): 2 x CogVideoXResnetBlock3D(
#           (nonlinearity): SiLU()
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): CogVideoXCausalConv3d(
#             (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): CogVideoXCausalConv3d(
#             (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#           )
#         )
#       )
#     )
#     (norm_out): GroupNorm(32, 512, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): CogVideoXCausalConv3d(
#       (conv): CogVideoXSafeConv3d(512, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#     )
#   )
#   (decoder): CogVideoXDecoder3D(
#     (conv_in): CogVideoXCausalConv3d(
#       (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#     )
#     (mid_block): CogVideoXMidBlock3D(
#       (resnets): ModuleList(
#         (0-1): 2 x CogVideoXResnetBlock3D(
#           (nonlinearity): SiLU()
#           (norm1): CogVideoXSpatialNorm3D(
#             (norm_layer): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv_y): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             )
#             (conv_b): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             )
#           )
#           (norm2): CogVideoXSpatialNorm3D(
#             (norm_layer): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv_y): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             )
#             (conv_b): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#             )
#           )
#           (conv1): CogVideoXCausalConv3d(
#             (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): CogVideoXCausalConv3d(
#             (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#           )
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): CogVideoXUpBlock3D(
#         (resnets): ModuleList(
#           (0-3): 4 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (norm2): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): CogVideoXUpsample3D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (1): CogVideoXUpBlock3D(
#         (resnets): ModuleList(
#           (0): CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 512, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (norm2): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (conv_shortcut): CogVideoXSafeConv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (1-3): 3 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (norm2): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): CogVideoXUpsample3D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (2): CogVideoXUpBlock3D(
#         (resnets): ModuleList(
#           (0-3): 4 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (norm2): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): CogVideoXUpsample3D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (3): CogVideoXUpBlock3D(
#         (resnets): ModuleList(
#           (0): CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 256, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (norm2): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (conv_shortcut): CogVideoXSafeConv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (1-3): 3 x CogVideoXResnetBlock3D(
#             (nonlinearity): SiLU()
#             (norm1): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (norm2): CogVideoXSpatialNorm3D(
#               (norm_layer): GroupNorm(32, 128, eps=1e-06, affine=True)
#               (conv_y): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#               (conv_b): CogVideoXCausalConv3d(
#                 (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#               )
#             )
#             (conv1): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): CogVideoXCausalConv3d(
#               (conv): CogVideoXSafeConv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#             )
#           )
#         )
#       )
#     )
#     (norm_out): CogVideoXSpatialNorm3D(
#       (norm_layer): GroupNorm(32, 128, eps=1e-06, affine=True)
#       (conv_y): CogVideoXCausalConv3d(
#         (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       )
#       (conv_b): CogVideoXCausalConv3d(
#         (conv): CogVideoXSafeConv3d(16, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       )
#     )
#     (conv_act): SiLU()
#     (conv_out): CogVideoXCausalConv3d(
#       (conv): CogVideoXSafeConv3d(128, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#     )
#   )
# )

# %%
def encode_video(vae, video):
    video = video.to(vae.device, dtype=vae.dtype)
    video = video.permute(0, 2, 1, 3, 4)  # [B, C, F, H, W]
    with torch.no_grad(): latent_dist = vae.encode(video).latent_dist.sample() * vae.config.scaling_factor
    return latent_dist.permute(0, 2, 1, 3, 4).to(memory_format=torch.contiguous_format)

def decode_latents(vae, latents: torch.Tensor) -> torch.Tensor:
    latents = latents.permute(0, 2, 1, 3, 4)  # [batch_size, num_channels, num_frames, height, width]
    latents = 1 / vae.config.scaling_factor * latents

    with torch.no_grad(): frames = vae.decode(latents).sample
    return frames

# %%
z = encode_video(vae, uvs.permute(0,1,4,2,3).to("cuda"))
y = decode_latents(vae, z).squeeze(0).permute(1,2,3,0)

sampled = head.sampleFromUV(uvs.squeeze(0), "flameOut/__b.mp4")
final = head.sampleTo3D(sampledUV=sampled, savePath="flameOut/__c.mp4", dist=1.2)

faces = head.faces3d.cpu().numpy()
verts = final[0, ...].cpu().numpy()

trimesh.Trimesh(vertices=verts, faces=faces, process=True).export("flameOut/__i.ply")
# Out:
# b'ply\nformat binary_little_endian 1.0\ncomment https://github.com/mikedh/trimesh\nelement vertex 3910\nproperty float x\nproperty float y\nproperty float z\nelement face 9976\nproperty list uchar int vertex_indices\nend_header\n\n\x08\x1f\xbeP\xa8\xa1\xbe\x06M\xdb\xbfV\xb0\x1e\xbe$\xa2\xa0\xbeR?\xdb\xbf\xa5\x98 \xbe\xb5%\x9f\xbel\x9f\xdc\xbf\x8c?\x1d\xbe\x90\x14\x9e\xbeH.\xdc\xbfh\x86\x1b\xbe)\x9f\x9b\xbe\xe1\xd8\xdb\xbfF\x02\x1f\xbe\x0b;\x9c\xbe\x048\xdc\xbf\x84\x15\\\xbe\xdaq\xbe\xbeB^\xe7\xbf\xd0\xd2r\xbeb\xa8\xbd\xbe\t1\xe9\xbf\xce\xe3u\xbe&\x1c\xc6\xbe\x0cn\xe8\xbf\xce\xd1a\xbee\xdb\xc7\xbe\xe8\xde\xe6\xbf\xdc\xcdJ\xbe<\xcd\xd9\xbe\xcc\x87\xe2\xbfK\x1dP\xbe\t\xdd\xd3\xbe\x1a\xb4\xe3\xbf\xe2*U\xbe\x81\x94\xdd\xbe\xe6\x89\xe4\xbfj\x14J\xbe\x12\xf7\xdf\xbe\x19j\xe2\xbf\xca\\X\xbeU\x81f\xbe\xc4p\xcb\xbff\xf8N\xbe\xa3\x80g\xbefa\xcc\xbfs\xd7O\xbe:\xc5p\xbe\x9c\xc8\xcb\xbf\x0e\xd5\xc0\xbe\x8b5\xa0\xbe\xf8\x0c\xdc\xbf\x8e\xa7\xc0\xbe\xa45\xa1\xbeJ\x19\xdc\xbf\x99\xfe\xbe\xbe\xa5\x8e\x9e\xbef\x93\xdd\xbf\xd5\xc0\xc0\xbe\x16n\x9d\xbe\xe6\xe0\xdc\xbf:-\xc2\xbe\x9b\x98\x9a\xbeWn\xdc\xbfw\x9a\xc0\xbe$9\x99\xbe\x13\x10\xdc\xbf[9Z\xbe;\xc7m\xbe\xa4\xe6\xca\xbf\xc9\xaa\x0b\xbe*\x11\x8d\xbe\xb0\x1c\xdd\xbf\xbb\x15\t\xbei\xa3\x8e\xbe\xd3]\xdd\xbf\x06\x80\x0e\xbe\xf0\x02\x9a\xbe\xb4\x9f\xde\xbfJ\xb8\r\xbe\x12q\x92\xbe8\x01\xde\xbfN\xfd\x0c\xbe\xf6\xe3\x90\xbe:\xa6\xdd\xbf\x1d\x12\x0e\xbe \xa0\xa3\xbeB\x89\xde\xbf\x19:\x0e\xbe\xfc/\x9e\xbe\xc2\xa2\xde\xbf\xa1:\r\xbe\xea\xa2\x9e\xbeL3\xdf\xbf\xb5\xeb \xbe\x08\xee\xb3\xbev\xfc\xda\xbf5f \xbe\x8c\xe7\xb1\xbe\xde\'\xdb\xbf\x01\x14\x1f\xbe\x1cv\xb3\xbe\xdeS\xdb\xbf\xa1Y!\xbe\x97\xe7\xb4\xbe\x19\xcf\xda\xbf=\xb5 \xbe\xcf\x0b\xb8\xbe\xe1\xb8\xda\xbfe\x8d\x1d\xbeEa\xb5\xbe\x11\x82\xdb\xbfL\x83\x19\xbe\x88\xef\xb7\xbeV\xfe\xdb\xbf\xbe\x93\x1e\xbe\xf2T\xb9\xbe!\x0c\xdb\xbf1\x88\x17\xbe\x15)\x8e\xbe&!\xdc\xbf\x0fy\x15\xbe)b\x8f\xbe\x96\xb6\xdb\xbf\xddD\x18\xbe\xb2\xcf\x8f\xbeB\x9d\xdb\xbf\x1cM\x19\xbe\xa2\x12\x8f\xbe~\xe5\xdb\xbf\x00<\x19\xbe\xfe#\xa4\xbe\xd91\xdf\xbf\xae\x83\x1d\xbe>\xbb\xa9\xbe|\xe6\xde\xbf\xbc^\r\xbe0\x10\xa6\xbet\x08\xe0\xbf\xe1\x94\x0f\xbe\xba\xaf\xa2\xbeW\x16\xe0\xbf\xb9\x91\x10\xbe\xcb\x8f\x92\xbe\x9c\x82\xdc\xbf\x1e\xd8\r\xbe\x1cj\x91\xbek\xb7\xdc\xbf4*\x12\xbe\x7f\xaf\x91\xbe\x80\x8f\xdc\xbf\xe4\x86\x11\xbe9\xc9\x8c\xbe$\x87\xdd\xbf\xa4]\x0e\xbe\x9cu\x8c\xbe\xf2\xd2\xdd\xbf@\x08$\xbe>\xc3\xae\xbe\x19l\xda\xbfWv$\xbe\xc64\xac\xbet\x00\xda\xbfj}"\xbeN\xeb\xaa\xbe\xc3y\xda\xbf`\xf9"\xbe\x86\x8b\xac\xbe\xe0\xb5\xda\xbf\xac\xdc\x1d\xbe\xf0g\x9f\xbe\xa4O\xdc\xbfb\n\x1c\xbe\x8e)\x9d\xbe.\xad\xdb\xbf\x14\x80\x12\xbe\xa5\xa7\xac\xbeo\xe5\xdd\xbf@\x80\x13\xbe\x1e\x08\xab\xbe\xa2\xb0\xdd\xbf |\x10\xbe\x9f{\xa8\xbe\xc8"\xde\xbfa\x9d\x0e\xbeE\xad\xa8\xbe\xc4f\xde\xbf\xf6e\x17\xbe\xaa^\xaa\xbe\xcc\xfb\xdd\xbf\x10\xe0\x13\xbe\xb4\x1c\xa7\xbe4K\xde\xbfol\x10\xbe\xe8\xed\xa6\xbe\xfe7\xde\xbf\x98\x9d\x13\xbe)\xc3\xa8\xbeL0\xde\xbf\x86J\x0f\xbeQ\x07\x8f\xbed*\xdc\xbf\x85\x05\x13\xbe\x0f\xe3\x8f\xbe\xc6\xca\xdb\xbf\xe6\x80\x15\xbe\xbe\xa6\x96\xbe\xca\xdd\xde\xbf\x831\x19\xbe\xa0\xaa\x94\xbe)\xd7\xdd\xbf\xa3\x06\x0c\xbeZu\x91\xbe\xd0>\xdd\xbf\x92\xf9\x0e\xbeC?\x91\xbe\xb0\xe1\xdc\xbf\xde\x1f\x18\xbe9H\x96\xbe\x9eS\xdb\xbf\x9b\xa6\x16\xbe\xb1\xe8\x94\xbe\x83^\xdb\xbf\xda\x8b\x16\xbe\r\xcb\x95\xbe\xcc\x83\xdb\xbf\x18\xae\x16\xbe\xe8\xa9\x96\xbeL\xad\xdb\xbf\x1fF\x1d\xbe\xba\x05\xb4\xbe\xd4\x9e\xdb\xbf\xfcR\x1e\xbe\xb4V\xb2\xbe\xe7p\xdd\xbfz-\x1a\xbe\n\xbb\xb2\xbe\xa0\xce\xdd\xbf\xeeZ\x15\xbe\xafl\xae\xbed\xd2\xde\xbff\x03\x19\xbe\x88R\xac\xbe\x0c\xb1\xde\xbfx\xd9$\xbe\xc0E\xb4\xbe\x9cU\xda\xbf\xca>"\xbe,O\xb3\xbe\xf3\xbe\xda\xbf}\x15#\xbeE%\xb5\xbe m\xda\xbf\xb7\xcd\x15\xbe\xbai\x93\xbe\xd3h\xdb\xbf\x10\xd7\x13\xbe\xc2\xae\x93\xbeD\xb7\xdb\xbf\xd3N\x15\xbe\xa1O\x94\xbe\n\x89\xdb\xbf6u\r\xbe\xaf\xf9\x94\xbez[\xde\xbf\x98\xe8\x10\xbe\xae\xaf\x91\xbe^:\xdd\xbfb\x88\x13\xbe\xafm\x9e\xbe.\xd3\xdd\xbf{\xfd\x0f\xbe$\xde\xa1\xbea2\xde\xbf\xce\xb2\xa2\xbe\x994\xbe\xbeq\xf1\xe7\xbf\xecU\x96\xbe\x8a\xbf\xbd\ ...
